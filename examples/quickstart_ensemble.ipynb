# %% [markdown]
# # 🧬 Quick Start: Differentiable IDP Ensemble Prediction
#
# Use a Variational Autoencoder (VAE) to predict structural ensembles constrained by physical data.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/elkins/diff-ensemble/blob/main/examples/quickstart_ensemble.ipynb)

# %%
# !pip install diff-ensemble matplotlib

# %% [markdown]
# ## Predict Conformational Ensembles
# We'll sample a flexible ensemble and plot its population average.

# %%
from diff_ensemble.model import EnsembleVAE

# Initialize a small IDP model (10 residues)
model = EnsembleVAE(seq_len=10, latent_dim=16)

print("Model initialized. In a full run, we would now train on SAXS data.")
print("DiffEnsemble enables gradient flow from experimental observables back to the VAE latent space.")
